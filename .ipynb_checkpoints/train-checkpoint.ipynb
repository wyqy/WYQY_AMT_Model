# %% [markdown]
# # DL based Onsets & Offsets Transcription of Piano
# ___
# by WYQY

# %% [markdown]
# # 1. Initialization

# %%
# import modules
import os
import time
import random
import importlib
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
# setup magic function
# %load_ext tensorboard
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
# import projects
import src.component.initial as initial
import src.component.util as util
import src.component.pre_spec_transform as spec_transform
import src.component.pre_sheet_transform as sheet_transform
import src.component.model_preprocessing as model_preprocessing
# import CNN models
import src.component.model_cnn_common as model_cnn_common
import src.component.model_cnn_build as model_cnn_build
import src.component.model_cnn_train as model_cnn_train
import src.component.model_cnn_inference as model_cnn_inference
import src.component.model_cnn_eval as model_cnn_eval
# import RNN models

# %%
# test
# 输出Tensorflow版本信息, 检查GPU
# 在Tensorflow2.4.0 (GPU@CUDA11.0@cuDNN8.0.4) Tensroflow_Addons0.12.1版本上检查通过
# 若GPU无法找到, 请至配置文件中自定义xfa路径并重新初始化
print(tf.__version__)
print(tf.keras.__version__)
print(tfa.__version__)
print('GPU', tf.config.list_physical_devices('GPU'))
# Out:
# 2.4.1
# 2.4.0
# 0.12.1
# GPU [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# (备用) 重载入模块
# base
importlib.reload(initial)
importlib.reload(util)
importlib.reload(spec_transform)
importlib.reload(sheet_transform)
importlib.reload(model_preprocessing)
# CNN model
importlib.reload(model_cnn_common)
importlib.reload(model_cnn_build)
importlib.reload(model_cnn_train)
importlib.reload(model_cnn_inference)
# RNN model
# Out:
# <module 'src.component.model_cnn_inference' from 'f:\\Download Files\\Study\\Academic\\毕设\\WYQY_Model\\src\\component\\model_cnn_inference.py'>

# %% [markdown]
# # 2. Data Initialization & Spectrum Test

# %% [markdown]
# ## 2.1) Data Initialization

# %%
# (可选) 预处理频谱数据删除
model_preprocessing.delete_spec_preprocess()
# Out:
# trainsets percentage: 100.0 [210/210]
# testests percentage: 100.0 [60/60]

# %%
# (可选) 预处理曲谱数据删除
model_preprocessing.delete_sheet_preprocess()
# Out:
# trainsets percentage: 100.0 [210/210]
# testests percentage: 100.0 [60/60]

# %%
# 频谱数据预处理
model_preprocessing.spec_preprocess()
# Out:
# trainsets percentage: 100.0 [210/210]
# testests percentage: 100.0 [60/60]

# %%
# 曲谱数据预处理
model_preprocessing.sheet_preprocess()
# Out:
# trainsets percentage: 100.0 [210/210]
# testests percentage: 100.0 [60/60]

# %% [markdown]
# ## 2.2) Spectrogram & PianoRoll Test

# %% [markdown]
# ### logMel Spectrum
# ___

# %%
# 测试指定位置的wav文件logMel频谱, 并画图
spec_logmel = spec_transform.rs_spec_logMel(sr=initial.config['spec.logmel.sampling'],
                                            lower_edge_hertz=initial.config['spec.logmel.lower.edge'],
                                            upper_edge_hertz=initial.config['spec.logmel.upper.edge'],
                                            hop_length=initial.config['spec.logmel.hop_length'],
                                            frame_length=initial.config['spec.logmel.frame_length'],
                                            n_mel=initial.config['spec.logmel.n_mel'],
                                            fft_length=initial.config['spec.logmel.fft_length'],
                                            window=initial.config['spec.logmel.window'])
time_start = time.time()
out = spec_logmel(
    'data\\MAPS_MUS-bk_xmas1_ENSTDkAm.wav')
time_end = time.time()
print(time_end - time_start)
print(out.shape)
# 画图
util.plot_single_transform(out[0:1024, :, 0])
# Out:
# G:\Program-Files\Anaconda\envs\tensorflow\lib\site-packages\librosa\util\utils.py:198: UserWarning: librosa.util.frame called with axis=-1 on a non-contiguous input. This will result in a copy.
#   warnings.warn(
# 19.106899976730347
# (48163, 229, 2)

# %% [markdown]
# ### CQT Spectrum
# ___

# %%
# 测试指定位置的wav文件CQT频谱, 并画图
spec_cqt = spec_transform.rs_spec_cqt(n_bins=initial.config['spec.cqt.n_bins'],
                                      bins_per_octave=initial.config['spec.cqt.bins_per_octave'],
                                      fmin=initial.config['spec.cqt.fmin'],
                                      frame_length=initial.config['spec.cqt.frame_length'],
                                      hop_length=initial.config['spec.cqt.hop_length'],
                                      window=initial.config['spec.cqt.window'])
time_start = time.time()
out = spec_cqt(
    'data\\MAPS_MUS-bk_xmas1_ENSTDkAm.wav')
time_end = time.time()
print(time_end - time_start)
print(out.shape)
# 画图
util.plot_single_transform(out[-1024:, :, 0])
# Out:
# 15.880797386169434
# (33195, 356, 2)

# %% [markdown]
# ### Piano-Roll Test
# ___

# %%
ms_sheet = sheet_transform.midi_trans_start(
        'data\MAPS_MUS-bk_xmas1_ENSTDkAm.mid', 'data\MAPS_MUS-bk_xmas1_ENSTDkAm.wav')
cs_sheet = sheet_transform.midi_trans_common(
        'data\MAPS_MUS-bk_xmas1_ENSTDkAm.mid', 'data\MAPS_MUS-bk_xmas1_ENSTDkAm.wav')
md_sheet = sheet_transform.midi_trans_duration(
        'data\MAPS_MUS-bk_xmas1_ENSTDkAm.mid', 'data\MAPS_MUS-bk_xmas1_ENSTDkAm.wav')

# %%
util.plot_single_transform(ms_sheet[0:1024, :], 'gray_r')

# %% [markdown]
# ### Alignment Test
# ___

# %%
# 测试预处理后的频谱和曲谱对齐
gen = model_cnn_common.Train_CNN_DataGenerator(io='test', output='multitone_duration')
g = gen()

# %%
# 可反复测试
y = next(g)
print(y[0].shape, y[1].shape)
print(np.min(y[0][:, :, :, 0]), np.max(y[0][:, :, :, 0]),
      np.mean(y[0][:, :, :, 0]), np.std(y[0][:, :, :, 0]))
# (1024, 9, 356, 2) (1024, 88)
util.plot_dual_transform(y[0][:, 0, :, 1], y[1][:, :])
# Out:
# (1024, 9, 356, 2) (1024, 88)
# 0.0 0.97954154 0.45562208 0.15939295

# %%
offest = 128
piece = 4
util.plot_dual_transform(y[0][offest:offest+128, piece, :, 1], y[1][offest:offest+128, :])

# %%
offest = 36
util.plot_single_transform(y[0][offest, :, :, 1])

# %% [markdown]
# # 3. CNN Model

# %% [markdown]
# ## 3.1) Multi-tone Starting Model

# %% [markdown]
# ### Model Build
# ___

# %%
start_tone_model = model_cnn_build.detect_multitone_model_cnn_build(needPrint=True)
# Out:
# Model: "multitone_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# spec_input (InputLayer)      [(None, 9, 356, 2)]       0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 8, 341, 10)        650
# _________________________________________________________________
# bn_1 (BatchNormalization)    (None, 8, 341, 10)        40
# _________________________________________________________________
# relu_1 (LeakyReLU)           (None, 8, 341, 10)        0
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 8, 171, 10)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 6, 160, 20)        7220
# _________________________________________________________________
# bn_2 (BatchNormalization)    (None, 6, 160, 20)        80
# _________________________________________________________________
# relu_2 (LeakyReLU)           (None, 6, 160, 20)        0
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 6, 80, 20)         0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 4, 72, 40)         21640
# _________________________________________________________________
# bn_3 (BatchNormalization)    (None, 4, 72, 40)         160
# _________________________________________________________________
# relu_3 (LeakyReLU)           (None, 4, 72, 40)         0
# _________________________________________________________________
# pool_3 (MaxPooling2D)        (None, 2, 36, 40)         0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 1, 32, 80)         32080
# _________________________________________________________________
# bn_4 (BatchNormalization)    (None, 1, 32, 80)         320
# _________________________________________________________________
# relu_4 (LeakyReLU)           (None, 1, 32, 80)         0
# _________________________________________________________________
# reshape_5 (Flatten)          (None, 2560)              0
# _________________________________________________________________
# fc_5 (Dense)                 (None, 256)               655616
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# relu_5 (LeakyReLU)           (None, 256)               0
# _________________________________________________________________
# fc_6 (Dense)                 (None, 88)                22616
# =================================================================
# Total params: 740,422
# Trainable params: 740,122
# Non-trainable params: 300
# _________________________________________________________________

# %% [markdown]
# ### Model Train & Test
# ___

# %%
# %tensorboard --logdir "models\tensorboard\multitone_start"
# for vscode: ctrl+shift+p, Python: Launch Tensorboard
# 如果需要接续训练, 请在此写入checkpoint路径
# models\checkpoint\multitone_start\chckpt_???.hdf5
ckpt_path = ''
start_tone_train = model_cnn_train.train_model(model=start_tone_model,
                                               type='multitone_start',
                                               resume=False,
                                               ckpt_path=ckpt_path)
mts_history, mts_loss = start_tone_train()
# Out:
# Epoch 1/30
# 4162/4162 [==============================] - 328s 78ms/step - loss: 0.6250 - macro_binary_fb_evaluation: 0.1038
# Epoch 2/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.2792 - macro_binary_fb_evaluation: 0.2726
# Epoch 3/30
# 4162/4162 [==============================] - 311s 75ms/step - loss: 0.2174 - macro_binary_fb_evaluation: 0.3660
# Epoch 4/30
# 4162/4162 [==============================] - 311s 75ms/step - loss: 0.2153 - macro_binary_fb_evaluation: 0.3703
# Epoch 5/30
# 4162/4162 [==============================] - 311s 75ms/step - loss: 0.2122 - macro_binary_fb_evaluation: 0.3746
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 6/30
# 4162/4162 [==============================] - 311s 75ms/step - loss: 0.1577 - macro_binary_fb_evaluation: 0.3680
# Epoch 7/30
# 4162/4162 [==============================] - 311s 75ms/step - loss: 0.1400 - macro_binary_fb_evaluation: 0.4135
# Epoch 8/30
# 4162/4162 [==============================] - 314s 75ms/step - loss: 0.1349 - macro_binary_fb_evaluation: 0.4283
# Epoch 9/30
# 4162/4162 [==============================] - 314s 75ms/step - loss: 0.1319 - macro_binary_fb_evaluation: 0.4382
# Epoch 10/30
# 4162/4162 [==============================] - 308s 74ms/step - loss: 0.1302 - macro_binary_fb_evaluation: 0.4431
# Epoch 11/30
# 4162/4162 [==============================] - 306s 74ms/step - loss: 0.1288 - macro_binary_fb_evaluation: 0.4458
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# Epoch 12/30
# 4162/4162 [==============================] - 306s 74ms/step - loss: 0.1242 - macro_binary_fb_evaluation: 0.4066
# Epoch 13/30
# 4162/4162 [==============================] - 310s 74ms/step - loss: 0.1169 - macro_binary_fb_evaluation: 0.4271
# Epoch 14/30
# 4162/4162 [==============================] - 313s 75ms/step - loss: 0.1155 - macro_binary_fb_evaluation: 0.4337
# Epoch 15/30
# 4162/4162 [==============================] - 313s 75ms/step - loss: 0.1146 - macro_binary_fb_evaluation: 0.4372
# Epoch 16/30
# 4162/4162 [==============================] - 314s 75ms/step - loss: 0.1141 - macro_binary_fb_evaluation: 0.4384
# Epoch 17/30
# 4162/4162 [==============================] - 307s 74ms/step - loss: 0.1134 - macro_binary_fb_evaluation: 0.4414
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# Epoch 18/30
# 4162/4162 [==============================] - 307s 74ms/step - loss: 0.1154 - macro_binary_fb_evaluation: 0.4210
# Epoch 19/30
# 4162/4162 [==============================] - 306s 73ms/step - loss: 0.1130 - macro_binary_fb_evaluation: 0.4349
# Epoch 20/30
# 4162/4162 [==============================] - 306s 74ms/step - loss: 0.1126 - macro_binary_fb_evaluation: 0.4364
# Epoch 21/30
# 4162/4162 [==============================] - 307s 74ms/step - loss: 0.1123 - macro_binary_fb_evaluation: 0.4373
# Epoch 22/30
# 4162/4162 [==============================] - 307s 74ms/step - loss: 0.1121 - macro_binary_fb_evaluation: 0.4378
# Epoch 23/30
# 4162/4162 [==============================] - 306s 74ms/step - loss: 0.1120 - macro_binary_fb_evaluation: 0.4385
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 24/30
# 4162/4162 [==============================] - 308s 74ms/step - loss: 0.1125 - macro_binary_fb_evaluation: 0.4340
# Epoch 25/30
# 4162/4162 [==============================] - 313s 75ms/step - loss: 0.1118 - macro_binary_fb_evaluation: 0.4391
# Epoch 26/30
# 4162/4162 [==============================] - 314s 76ms/step - loss: 0.1118 - macro_binary_fb_evaluation: 0.4393
# Epoch 27/30
# 4162/4162 [==============================] - 313s 75ms/step - loss: 0.1117 - macro_binary_fb_evaluation: 0.4397
# Epoch 28/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.1117 - macro_binary_fb_evaluation: 0.4398
# Epoch 29/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.1116 - macro_binary_fb_evaluation: 0.4402
# Epoch 30/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.1116 - macro_binary_fb_evaluation: 0.4405
# INFO:tensorflow:Assets written to: models\save\multitone_start\saved_2021-05-11-17_33_22\assets
# 1317/1317 [==============================] - 44s 33ms/step - loss: 0.2149 - macro_binary_fb_evaluation: 0.2620

# %% [markdown]
# ## 3.2) Common Starting Model

# %% [markdown]
# ### Model Build
# ___

# %%
start_common_model = model_cnn_build.detect_start_common_model_cnn_build(needPrint=True)
# Out:
# Model: "start_common_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# spec_input (InputLayer)      [(None, 9, 356, 2)]       0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 5, 341, 10)        1610
# _________________________________________________________________
# bn_1 (BatchNormalization)    (None, 5, 341, 10)        40
# _________________________________________________________________
# relu_1 (LeakyReLU)           (None, 5, 341, 10)        0
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 5, 171, 10)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 3, 160, 20)        7220
# _________________________________________________________________
# bn_2 (BatchNormalization)    (None, 3, 160, 20)        80
# _________________________________________________________________
# relu_2 (LeakyReLU)           (None, 3, 160, 20)        0
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 3, 80, 20)         0
# _________________________________________________________________
# reshape_3 (Flatten)          (None, 4800)              0
# _________________________________________________________________
# fc_3 (Dense)                 (None, 256)               1229056
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# relu_3 (LeakyReLU)           (None, 256)               0
# _________________________________________________________________
# fc_4 (Dense)                 (None, 1)                 257
# =================================================================
# Total params: 1,238,263
# Trainable params: 1,238,203
# Non-trainable params: 60
# _________________________________________________________________

# %% [markdown]
# ### Model Train & Test
# ___

# %%
# %tensorboard --logdir "models\tensorboard\common_start"
# for vscode: ctrl+shift+p, Python: Launch Tensorboard
# 如果需要接续训练, 请在此写入checkpoint路径
# models\checkpoint\common_start\chckpt_???.hdf5
ckpt_path = ''
start_common_train = model_cnn_train.train_model(model=start_common_model,
                                                 type='common_start',
                                                 resume=False,
                                                 ckpt_path=ckpt_path)
cs_history, cs_loss = start_common_train()
# Out:
# Epoch 1/30
# 4162/4162 [==============================] - 224s 53ms/step - loss: 1.3133 - macro_binary_fb_evaluation: 0.4024
# Epoch 2/30
# 4162/4162 [==============================] - 176s 42ms/step - loss: 0.3678 - macro_binary_fb_evaluation: 0.5249
# Epoch 3/30
# 4162/4162 [==============================] - 176s 42ms/step - loss: 0.3671 - macro_binary_fb_evaluation: 0.5332
# Epoch 4/30
# 4162/4162 [==============================] - 175s 42ms/step - loss: 0.3633 - macro_binary_fb_evaluation: 0.5352
# Epoch 5/30
# 4162/4162 [==============================] - 171s 41ms/step - loss: 0.3682 - macro_binary_fb_evaluation: 0.5316
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 6/30
# 4162/4162 [==============================] - 176s 42ms/step - loss: 0.3329 - macro_binary_fb_evaluation: 0.5388
# Epoch 7/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3282 - macro_binary_fb_evaluation: 0.5465
# Epoch 8/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3277 - macro_binary_fb_evaluation: 0.5463
# Epoch 9/30
# 4162/4162 [==============================] - 176s 42ms/step - loss: 0.3270 - macro_binary_fb_evaluation: 0.5461
# Epoch 10/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3269 - macro_binary_fb_evaluation: 0.5465
# Epoch 11/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3262 - macro_binary_fb_evaluation: 0.5481
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# Epoch 12/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3245 - macro_binary_fb_evaluation: 0.5420
# Epoch 13/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3208 - macro_binary_fb_evaluation: 0.5528
# Epoch 14/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3196 - macro_binary_fb_evaluation: 0.5565
# Epoch 15/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3185 - macro_binary_fb_evaluation: 0.5570
# Epoch 16/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3178 - macro_binary_fb_evaluation: 0.5577
# Epoch 17/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3168 - macro_binary_fb_evaluation: 0.5581
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# Epoch 18/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3180 - macro_binary_fb_evaluation: 0.5533
# Epoch 19/30
# 4162/4162 [==============================] - 177s 42ms/step - loss: 0.3163 - macro_binary_fb_evaluation: 0.5558
# Epoch 20/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3158 - macro_binary_fb_evaluation: 0.5581
# Epoch 21/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3155 - macro_binary_fb_evaluation: 0.5606
# Epoch 22/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3150 - macro_binary_fb_evaluation: 0.5613
# Epoch 23/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3148 - macro_binary_fb_evaluation: 0.5635
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 24/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3150 - macro_binary_fb_evaluation: 0.5632
# Epoch 25/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3147 - macro_binary_fb_evaluation: 0.5633
# Epoch 26/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3145 - macro_binary_fb_evaluation: 0.5633
# Epoch 27/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3145 - macro_binary_fb_evaluation: 0.5628
# Epoch 28/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3145 - macro_binary_fb_evaluation: 0.5629
# Epoch 29/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3144 - macro_binary_fb_evaluation: 0.5638
# Epoch 30/30
# 4162/4162 [==============================] - 177s 43ms/step - loss: 0.3144 - macro_binary_fb_evaluation: 0.5641
# INFO:tensorflow:Assets written to: models\save\common_start\saved_2021-05-11-14_56_40\assets
# 1317/1317 [==============================] - 48s 36ms/step - loss: 0.5535 - macro_binary_fb_evaluation: 0.3573

# %% [markdown]
# ## 3.3) Multi-tone Duration Model

# %% [markdown]
# ### Model Build
# ___

# %%
duration_tone_model = model_cnn_build.detect_multitone_model_cnn_build(needPrint=True)
# Out:
# Model: "multitone_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# spec_input (InputLayer)      [(None, 9, 356, 2)]       0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 8, 341, 10)        650
# _________________________________________________________________
# bn_1 (BatchNormalization)    (None, 8, 341, 10)        40
# _________________________________________________________________
# relu_1 (LeakyReLU)           (None, 8, 341, 10)        0
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 8, 171, 10)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 6, 160, 20)        7220
# _________________________________________________________________
# bn_2 (BatchNormalization)    (None, 6, 160, 20)        80
# _________________________________________________________________
# relu_2 (LeakyReLU)           (None, 6, 160, 20)        0
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 6, 80, 20)         0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 4, 72, 40)         21640
# _________________________________________________________________
# bn_3 (BatchNormalization)    (None, 4, 72, 40)         160
# _________________________________________________________________
# relu_3 (LeakyReLU)           (None, 4, 72, 40)         0
# _________________________________________________________________
# pool_3 (MaxPooling2D)        (None, 2, 36, 40)         0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 1, 32, 80)         32080
# _________________________________________________________________
# bn_4 (BatchNormalization)    (None, 1, 32, 80)         320
# _________________________________________________________________
# relu_4 (LeakyReLU)           (None, 1, 32, 80)         0
# _________________________________________________________________
# reshape_5 (Flatten)          (None, 2560)              0
# _________________________________________________________________
# fc_5 (Dense)                 (None, 256)               655616
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# relu_5 (LeakyReLU)           (None, 256)               0
# _________________________________________________________________
# fc_6 (Dense)                 (None, 88)                22616
# =================================================================
# Total params: 740,422
# Trainable params: 740,122
# Non-trainable params: 300
# _________________________________________________________________

# %% [markdown]
# ### Model Train & Test
# ___

# %%
# %tensorboard --logdir "models\tensorboard\multitone_duration"
# for vscode: ctrl+shift+p, Python: Launch Tensorboard
# 如果需要接续训练, 请在此写入checkpoint路径
# models\checkpoint\multitone_duration\chckpt_???.hdf5
ckpt_path = ''
duration_tone_train = model_cnn_train.train_model(model=duration_tone_model,
                                               type='multitone_duration',
                                               resume=False,
                                               ckpt_path=ckpt_path)
mtd_history, mtd_loss = duration_tone_train()
# Out:
# Epoch 1/30
# 4162/4162 [==============================] - 422s 100ms/step - loss: 3.3985 - macro_binary_fb_evaluation: 0.2383
# Epoch 2/30
# 4162/4162 [==============================] - 313s 75ms/step - loss: 1.3592 - macro_binary_fb_evaluation: 0.6037
# Epoch 3/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 1.2907 - macro_binary_fb_evaluation: 0.6456
# Epoch 4/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 1.2858 - macro_binary_fb_evaluation: 0.6522
# Epoch 5/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 1.2719 - macro_binary_fb_evaluation: 0.6534
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 6/30
# 4162/4162 [==============================] - 313s 75ms/step - loss: 1.0968 - macro_binary_fb_evaluation: 0.5859
# Epoch 7/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.9445 - macro_binary_fb_evaluation: 0.6414
# Epoch 8/30
# 4162/4162 [==============================] - 311s 75ms/step - loss: 0.9098 - macro_binary_fb_evaluation: 0.6568
# Epoch 9/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.8864 - macro_binary_fb_evaluation: 0.6689
# Epoch 10/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.8732 - macro_binary_fb_evaluation: 0.6761
# Epoch 11/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.8668 - macro_binary_fb_evaluation: 0.6787
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# Epoch 12/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.9134 - macro_binary_fb_evaluation: 0.5825
# Epoch 13/30
# 4162/4162 [==============================] - 312s 75ms/step - loss: 0.8193 - macro_binary_fb_evaluation: 0.6245
# Epoch 14/30
# 4162/4162 [==============================] - 308s 74ms/step - loss: 0.8015 - macro_binary_fb_evaluation: 0.6331
# Epoch 15/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7912 - macro_binary_fb_evaluation: 0.6378
# Epoch 16/30
# 4162/4162 [==============================] - 305s 73ms/step - loss: 0.7833 - macro_binary_fb_evaluation: 0.6413
# Epoch 17/30
# 4162/4162 [==============================] - 305s 73ms/step - loss: 0.7771 - macro_binary_fb_evaluation: 0.6445
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# Epoch 18/30
# 4162/4162 [==============================] - 305s 73ms/step - loss: 0.8393 - macro_binary_fb_evaluation: 0.5897
# Epoch 19/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7844 - macro_binary_fb_evaluation: 0.6190
# Epoch 20/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7723 - macro_binary_fb_evaluation: 0.6255
# Epoch 21/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7662 - macro_binary_fb_evaluation: 0.6289
# Epoch 22/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7620 - macro_binary_fb_evaluation: 0.6314
# Epoch 23/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7584 - macro_binary_fb_evaluation: 0.6335
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 24/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7694 - macro_binary_fb_evaluation: 0.6198
# Epoch 25/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7615 - macro_binary_fb_evaluation: 0.6267
# Epoch 26/30
# 4162/4162 [==============================] - 303s 73ms/step - loss: 0.7582 - macro_binary_fb_evaluation: 0.6289
# Epoch 27/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7563 - macro_binary_fb_evaluation: 0.6303
# Epoch 28/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7546 - macro_binary_fb_evaluation: 0.6310
# Epoch 29/30
# 4162/4162 [==============================] - 304s 73ms/step - loss: 0.7533 - macro_binary_fb_evaluation: 0.6315
# Epoch 30/30
# 4162/4162 [==============================] - 305s 73ms/step - loss: 0.7520 - macro_binary_fb_evaluation: 0.6325
# INFO:tensorflow:Assets written to: models\save\multitone_duration\saved_2021-05-11-13_25_53\assets
# 1317/1317 [==============================] - 55s 42ms/step - loss: 0.8645 - macro_binary_fb_evaluation: 0.5800

# %% [markdown]
# # 4. Evaluate

# %% [markdown]
# ## 4.1) Accurency Test

# %% [markdown]
# ### Multi-tone Starting Model
# ___

# %%
start_tone_model = model_cnn_build.detect_multitone_model_cnn_build()
# models\checkpoint\multitone_start\chckpt_???.hdf5
weight_path = initial.config['detect.model.multistart.weight']
start_tone_test = model_cnn_eval.test_model(model=start_tone_model,
                                            type='multitone_start',
                                            weight_path=weight_path)
mts_loss = start_tone_test()
# Out:
# 665/665 [==============================] - 62s 89ms/step - loss: 0.1993 - macro_binary_fb_evaluation: 0.2545

# %% [markdown]
# ### Common Starting Model
# ___

# %%
start_common_model = model_cnn_build.detect_start_common_model_cnn_build()
# models\checkpoint\common_start\chckpt_???.hdf5
weight_path = initial.config['detect.model.commonstart.weight']
start_common_test = model_cnn_eval.test_model(model=start_common_model,
                                              type='common_start',
                                              weight_path=weight_path)
cs_loss = start_common_test()
# Out:
# 665/665 [==============================] - 50s 74ms/step - loss: 0.5176 - macro_binary_fb_evaluation: 0.3412

# %% [markdown]
# ### Multi-tone Duration Model
# ___

# %%
duration_tone_model = model_cnn_build.detect_multitone_model_cnn_build()
# models\checkpoint\multitone_duration\chckpt_???.hdf5
weight_path = initial.config['detect.model.multiduration.weight']
duration_tone_test = model_cnn_eval.test_model(model=duration_tone_model,
                                               type='multitone_duration',
                                               weight_path=weight_path)
mtd_loss = duration_tone_test()
# Out:
# 665/665 [==============================] - 39s 58ms/step - loss: 0.8382 - macro_binary_fb_evaluation: 0.5678

# %% [markdown]
# ## 4.2) Diagram Test

# %%
diagram_test = model_cnn_inference.Transcription_Model(
    multitone_start_path = initial.config['detect.model.multistart.weight'],
    common_start_path = initial.config['detect.model.commonstart.weight'],
    multitone_duration_path = initial.config['detect.model.multiduration.weight'])
diagrams = diagram_test.sheet_plot('data\MAPS_MUS-bk_xmas1_ENSTDkAm.wav')

# %% [markdown]
# ### Multi-tone Starting Model
# ___

# %%
diagram = np.where(diagrams[0]>0.5, 1.0, 0.0)
util.plot_single_transform(diagram[0:1024, :], cmap='gray_r')

# %% [markdown]
# ### Common Starting Model
# ___

# %%
diagram = np.where(diagrams[1]>0.5, 1.0, 0.0)
util.plot_single_transform(diagram[0:1024, :], cmap='gray_r')

# %% [markdown]
# ### Multi-tone Duration Model
# ___

# %%
diagram = np.where(diagrams[2]>0.5, 1.0, 0.0)
util.plot_single_transform(diagram[0:1024, :], cmap='gray_r')

# %% [markdown]
# ## 4.3) Predict Test

# %%
predict_test = model_cnn_inference.Transcription_Model(
    multitone_start_path = initial.config['detect.model.multistart.weight'],
    common_start_path = initial.config['detect.model.commonstart.weight'],
    multitone_duration_path = initial.config['detect.model.multiduration.weight'])
piano_roll, notes = predict_test.notes_plot('data\MAPS_MUS-bk_xmas1_ENSTDkAm.wav')

# %%
util.plot_single_transform(piano_roll[0:1024, :], cmap='gray_r')

# %% [markdown]
# ## 4.4) mir_eval Test

# %%
eval_result = model_cnn_eval.note_evaluation(
    multitone_start_path = initial.config['detect.model.multistart.weight'],
    common_start_path = initial.config['detect.model.commonstart.weight'],
    multitone_duration_path = initial.config['detect.model.multiduration.weight']
)

# %%
eval_result
# Out:
# array([0.45884493, 0.35925782, 0.40028897, 0.84264654, 0.8385829 ,
#        0.64908123, 0.7267295 , 0.6755955 , 0.89045614, 0.6872305 ,
#        0.77037865, 0.739603  , 0.57344043, 0.6416438 ], dtype=float32)
